# %%
#There is one question and different and improved versions.
##Question:- Write a program

# %%
#write a programme that store name and age  This is version-1
list_name=['amit','james']
list_age=[23,25]
list_age+list_name
# Out:
# [23, 25, 'amit', 'james']

# %%
#This is version-2  [ In this version only 1 input per list is taken. So expected output is like ['John',31]
lst_name=[]
lst_age=[]
lst_name.append(input('Enter your name').title().strip())
lst_age.append(int(input('Enter your age')))
lst_name_age= (lst_name)+(lst_age)
print(lst_name_age)
# Out:
# ['Adam', 23]

# %%
# This is Version-3 [ In this version, 5 input per list.][change the while condition and can be adjusted as per needed].stops after 5 input automatic.
i=1
total = {}
while i !=6:

    name=input('Enter your name').title().strip()
    age=int(input('Enter your age'))

    total[name]= age #stores name as key and age as value.
    print("Name:",name,"Age:",age)
    i=i+1
print("Summary",total)

#learned placement of syntax makes all the impact.
#Summary is printed in one line only not as a list.
# Out:
# Name: Amit Age: 12
# Name: Eric Age: 31
# Name: Tero Age: 43
# Name: John Age: 19
# Name: Sam Age: 20
# Summary {'Amit': 12, 'Eric': 31, 'Tero': 43, 'John': 19, 'Sam': 20}

# %%
#This is my version 4 [ In this version I tried to create a programme for the user to store as many name and age user want to store.
#Create Dictionary outside the loop.

total = {}   # dictionary to store name: age

start_input = input("Press Any Key to Start the programme: ")
print("Welcome to Data Entry Simulator.\n.................Type 'start' to start. Type 'quit' to exit")

while start_input != "quit":
    command = input("Enter your command (start or quit): ").lower().strip()

    if command == "start":
        print("Program Started......")
        name = input("Enter your name: ").title().strip()
        age = int(input("Enter your age: "))
        total[name] = age
        print("Name:", name, "Age:", age)

    elif command == "quit":
        print("Summary")
        print(total)
        break

    else:
        print("Invalid command. Type 'start' or 'quit'.")

#Program works....but frustrating. Every time I type name and age, I need to write start or stop.
# Out:
# Welcome to Data Entry Simulator.
# .................Type 'start' to start. Type 'quit' to exit
# Program Started......
# Name: Amit Age: 23
# Summary
# {'Amit': 23}

# %%
#This is my version -5 [ In this version I tried to create a program for the user to store as many name and age user want to store.
#Ask command only after 10 entries

total = {}   # dictionary to store name: age

start_input = input("Press Any Key to Start the programme: ")
print("Welcome to Data Entry Simulator.\n.................Type 'start' to start. Type 'quit' to exit")

while start_input != "quit":
    command = input("Enter your command (start or quit): ").lower().strip()

    if command == "start":
        print("Program Started......")

        for i in range(10):   # loop for 10 entries
            name = input("Enter your name: ").title().strip()
            age = int(input("Enter your age: "))
            total[name] = age
            print("Name:", name, "Age:", age)

        print("\n10 entries completed\n...............Break Time................")

    elif command == "quit":
        print("Summary")
        print("\n",total)
        break

    else:
        print("Invalid command. Type 'start' or 'quit'.")
        # problem:-Summary in 1 line. I need a list
# Out:
# Welcome to Data Entry Simulator.
# .................Type 'start' to start. Type 'quit' to exit
# Invalid command. Type 'start' or 'quit'.
# Program Started......
# Name: Amit Age: 13
# Name: Ram Age: 21
# Name: Shyam Age: 19
# Name: Arya Age: 87
# Name: Rock Age: 32
# Name: Will Age: 21
# Name: Bill Age: 43
# Name: Jill Age: 74
# Name: Tim Age: 21
# Name: Tom Age: 21
#
# 10 entries completed
# ...............Break Time................
# Summary
#
#  {'Amit': 13, 'Ram': 21, 'Shyam': 19, 'Arya': 87, 'Rock': 32, 'Will': 21, 'Bill': 43, 'Jill': 74, 'Tim': 21, 'Tom': 21}

# %%
#version 6. Summary in separate line like a list. breaktime after every 10 entries
total = {}

start_input = input("Press Any Key to Start the programme: ")
print("Welcome to Data Entry Simulator.\n.................Type 'start' to start. Type 'quit' to exit")

while start_input != "quit":
    command = input("Enter your command (start or quit): ").lower().strip()

    if command == "start":
        print("Program Started......")

        for i in range(10):   # loop for 10 entries
            name = input("Enter your name: ").title().strip()
            age = int(input("Enter your age: "))
            total[name] = age
            print("Name:", name, "Age:", age)

        print("\n10 entries completed\n...............Break Time................")

    elif command == "quit":
        print("\nSummary\n")
        for name, age in total.items():
            print(name, ":", age)
        break

    else:
        print("Invalid command. Type 'start' or 'quit'.")
    #Cons: Have to do 10 entries once you press start. If you try to break the loop it gives error.
# Out:
# Welcome to Data Entry Simulator.
# .................Type 'start' to start. Type 'quit' to exit
# Program Started......
# Name: Enrique Age: 21
# Name: Watson Age: 65
# Name: Danny Age: 32
# Name: Rick Age: 21
# Name: Correy Age: 25
# Name: Alex Age: 28
# Name: Rim Age: 24
# Name: Jim Age: 32
# Name: Joy Age: 19
# Name: Ursulla Age: 24
#
# 10 entries completed
# ...............Break Time................
# Invalid command. Type 'start' or 'quit'.
# Summary
# Enrique : 21
# Watson : 65
# Danny : 32
# Rick : 21
# Correy : 25
# Alex : 28
# Rim : 24
# Jim : 32
# Joy : 19
# Ursulla : 24

# %%
#version 7. Change value error as summary for better view.

total = {}

start_input = input("Press Any Key to Start the programme: ")
print("Welcome to Data Entry Simulator.\n.................Type 'start' to start. Type 'quit' to exit")

while start_input != "quit":
    command = input("Enter your command (start or quit): ").lower().strip()

    if command == "start":
        print("Program Started......")

        try:
            for i in range(10):   # loop for 10 entries
                name = input("Enter your name: ").title().strip()

                # If user presses Enter without typing a name
                if name == "":
                    raise ValueError("Empty name")

                age = int(input("Enter your age: "))  # may cause ValueError

                total[name] = age
                print("Name:", name, "Age:", age)

            print("\n10 entries completed\n...............Break Time................")

        except ValueError:
            print("\nValueError occurred! User stopped early or entered invalid data.")
            print("Printing summary before exiting...\n\n............Summary.............\n")
            for name, age in total.items():
                print(name, ":", age)
            break

    elif command == "quit":
        print("Summary")
        for name, age in total.items():
            print(name, ":", age)
        break

    else:
        print("Invalid command. Type 'start' or 'quit'.")
   #command line tsted.pass
   #tested for less than 10 entries.Pass
    #tested for 10 entries works good, quit goods.pass
    #tested for 15 entries. gives valueerror -summary- full.....pass
# Out:
# Welcome to Data Entry Simulator.
# .................Type 'start' to start. Type 'quit' to exit
# Invalid command. Type 'start' or 'quit'.
# Program Started......
# Name: Andrew Age: 23
# Name: Peter Age: 32
# Name: Dimellow Age: 32
#
# ValueError occurred! User stopped early or entered invalid data.
# Printing summary before exiting...
# ............Summary.............
#
# Andrew : 23
# Peter : 32
# Dimellow : 32

# %%
#{version8- for unlimited entries. This is an ultimate program.used copilot for some logic and code fixing. need to fix it further.
#fix needed at age check output for better understand.
#fix value error

total = {}

start_input = input("Press Any Key to Start the programme: ")
print("Welcome to Data Entry Simulator.\n.................Type 'start' to start. Type 'quit' to exit")

while True:
    command = input("Enter your command (start or quit): ").lower().strip()

    if command == "start":
        print("Program Started......")

        for i in range(10):   # loop for 10 entries
            name = input("Enter your name (or type 'quit' to stop): ").title().strip()

            if name.lower() == "quit":
                print("Summary")
                for n, a in total.items():
                    print(n, ":", a)
                exit()

            age = int(input("Enter your age: ")) #Fix needed
            total[name] = age
            print("Name:", name, "Age:", age)

        print("\n10 entries completed\n...............Break Time................")

    elif command == "quit":
        print("Summary")
        for name, age in total.items():
            print(name, ":", age)
        break

    else:
        print("Invalid command. Type 'start' or 'quit'.")
